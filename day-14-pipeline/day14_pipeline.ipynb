# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhhiiissshhek/100_days_of_ML_challenge/blob/main/day-14-pipeline/day14_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Day 14 / 100**

# %% [markdown]
# ### **THE PROBLEM: MESSY WORKFLOW**

# %%
# Step 1: Scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)   # Often bhool jaate!

# Step 2: Train
model = LogisticRegression()
model.fit(X_train_scaled, y_train)

# Step 3: Predict
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# ## **MISTAKES = DATA LEAKAGE ⚠️**

# %% [markdown]
# # **SOLUTION: PIPELINE**

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', LogisticRegression())
])

# ONE line - fit karo
pipeline.fit(X_train, y_train)

# ONE line - predict karo
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ## **AUTOMATIC! 🤖**

# %% [markdown]
# # **HOW PIPELINE WORKS**

# %% [markdown]
# X_train ──→ [SCALER] ──→ [MODEL] ──→ y_pred
#               ↓            ↓
#            fit()        fit()
#
# X_test  ──→ [SCALER] ──→ [MODEL] ──→ y_pred
#               ↓            ↓
#          transform()    predict()

# %% [markdown]
# ## **NO DATA LEAKAGE! ✅**
